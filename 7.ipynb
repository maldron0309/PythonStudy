# %% [markdown]
# 파이썬은 정말 많은 일들을 할 수 있고, 이를 위해 여러가지 모듈과 패키지를 제공하고 있습니다. 모듈과 패키지를 배우고 이를 어떻게 사용하는지, 어떻게 만드는지 배워봅시다.

# %% [markdown]
# ### [이론1] 모듈

# %% [markdown]
# ppt

# %% [markdown]
# ### [퀴즈1] 모듈

# %% [markdown]
# Q.특정 목적을 가진 함수, 자료의 모임을 의미하는 말은 무엇인가요?
# 1. 딕셔너리
# 2. 모듈
# 3. 튜플
#
# 정답 : 2

# %% [markdown]
# ### [이론2] 모듈 사용하기

# %% [markdown]
# ppt

# %% [markdown]
# ### [퀴즈2] 모듈 사용하기

# %% [markdown]
# Q.모듈 cal을 불러오는 방법으로 올바른 것을 골라주세요.
# 1. import cal()
# 2. import cal.py
# 3. import cal
#
# 정답 :  3

# %% [markdown]
# ### [실습1] 모듈 만들기

# %% [markdown]
# **계산기 모듈을 직접 만들어봅시다!**
#
# random, math와 같이 이미 다른 개발자들이 만들어놓은 모듈도 있지만, 직접 우리가 모듈을 만들어서 사용할 수도 있습니다! 이번 실습에서는 모듈을 직접 만들어보고, 사용해보겠습니다.
#
# ---
# cal.py 모듈은 계산기 기능이 담긴 모듈입니다. 이 안에는 plus() 와 minus() 함수가 있고, 모델명이 담긴 변수 modelName이 있습니다. 오른쪽 실습에서 직접 이 cal.py를 만들어보고, main.py에서 이를 불러와봅시다.
#
# **이렇게 해봐요!**
# 1. cal.py 파일을 열고, a,b를 인자로 갖는 함수 plus, minus를 정의해봅니다.
# - plus : a+b를 반환하는 함수
# - minus : a-b를 반환하는 함수
# 2. cal.py 파일에서 변수 modelName을 만들고 ‘ELI-C2’를 대입해봅시다.
#
# 3. main.py 파일을 열고, import cal을 이용해 저장된 모듈 cal을 불러와봅시다.
#
# 4. 변수 var1에 모듈 cal의 모델이름(modelName)을 넣어봅시다.
#
# 5. 변수 var2에 모듈 cal의 plus 함수를 이용해서 3+4의 값을 넣어봅시다.
#
# 6. 변수 var3에 모듈 cal의 minus 함수를 이용해서 7-2의 값을 넣어봅시다.
#
# 7. var1, var2, var3의 값을 출력하여 확인해봅시다.

# %%
import math
import random

import main

math.log(10, 10)
math.ceil(3.14)
math.fabs(-3.14)
math.factorial(5)
math.floor(3.14)
math.gcd(6, 8)

r = random
r.random()
r.randrange(1, 7)
abc = [1, 2, 3, 4, 5, 6, 7, 8, 9]
r.shuffle(abc)
print(abc)

r.choice([True, False])

# 변수의 값을 확인하는 출력문입니다.
print(main.var1, main.var2, main.var3)

# %%
# cal.py

# 함수 정의
def plus(a, b):
    return a + b

def minus(a, b):
    return a - b

modelName = "ELI-C2"

# %%
# main.py

# cal 모듈 불러오기
import cal

# 모듈의 변수와 함수 사용
var1 = cal.modelName
var2 = cal.plus(3, 4)
var3 = cal.minus(7, 2)

# 결과 출력
print(var1, var2, var3)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-36ab03e2cbfd> in <cell line: 4>()
#       2
#       3 # cal 모듈 불러오기
# ----> 4 import cal
#       5
#       6 # 모듈의 변수와 함수 사용
#
# ModuleNotFoundError: No module named 'cal'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ### [이론3] 모듈 활용하기

# %% [markdown]
# PPT

# %% [markdown]
# ### [퀴즈3] 모듈 활용하기

# %% [markdown]
# Q.다음 코드에 이어서 1 이상 11 미만의 수 중 하나를 반환하는 코드를 올바르게 작성한 것은 무엇일까요?
# 1. import random
# 2. random(1,11)
# 3. randrange(1,11)
# 4. random.randrange(1,11)
#
# 정답 : 4

# %% [markdown]
# ### [실습2] 모듈 활용 : time

# %% [markdown]
# **시간이 똑…딱… 지나가네요**
#
# time 모듈에는 현재 시간을 알려주는 함수인 time.ctime()이 있습니다.
#
# - time.ctime() : “요일 월 일 시간 년” 순으로 현재 시간을 문자열로 반환해주는 함수
#
# ---
# 엘리스가 길을 가고 있는데, 거대한 문을 발견했어요! 이곳에는 다음과 같이 글귀가 써있었답니다.
#
# >이 문을 열기 위해선, 짝수 분에 문을 두들겨라. 35분이 아닌 36분에 말이다.
#
# 문 안에 무엇이 있는지 궁금한 엘리스는 짝수 분에 문을 열기로 합니다. 그런데 엘리스는 집에 회중시계를 두고와 시간을 확인할 수가 없네요! time 모듈을 이용해서 우리가 엘리스를 도와줍시다.
#
# **이렇게 해봐요!**
# 1. 변수 clock에 현재 시각이 “요일 월 일 시간 년” 순으로 나열된 문자열을 담아봅시다.
#
# 2. 짝수 분에 제출 버튼을 눌러 엘리스가 문을 두들기도록 해봅시다.

# %%
import time

clock = time.ctime()

if int(time.strftime("%M")) % 2 == 0:
    print("문을 엽니다.")
else:
    print("NOPE")
# Out:
# NOPE

# %% [markdown]
# ### [실습3] 모듈 활용 : math

# %% [markdown]
# **Python의 math 모듈로 쉽게 수학문제를 풀 수 있습니다!**
#
# 수학에서 로그는 다음과 같이 정의됩니다.
#
# a^{x} = b 일때, x = log_{a}b 입니다.
#
# 이때 a는 밑, b는 진수라고 합니다.
#
# Python에서 이를 쉽게 풀 수 있는 모듈과 함수가 있습니다. 바로 math 모듈입니다. math 모듈을 이용해서 위의 로그를 표현하면 다음과 같습니다.
#
# >import math
# print(math.log(b, a))
#
# 다음은 2016학년도 6월 모의평가 A형 2번 문제입니다. 이 문제를 위의 math 모듈과 math.log(b, a)를 이용해서 정답을 출력해봅시다.
#
# ![sooneung.png](data:image/png;base64,...)
#
# **이렇게 해봐요!**
# 1. math 모듈을 import 해봅시다.
#
# 2. math.log(b, a)를 이용해서 주어진 문제의 정답을 출력해봅시다.

# %%
import math

a = 2
b = 16

x = math.log(b, a)

print(x)

# %% [markdown]
# ### [이론4] 패키지

# %% [markdown]
# PPT

# %% [markdown]
# ### [퀴즈4] 패키지

# %% [markdown]
# Q.user 패키지의 math 모듈에서 log 함수를 불러오려고 할 때, 알맞은 코드를 고르세요.
# 1. from user import log
# 2. from user.math import log
# 3. from user import math.log
#
# 정답 :  3

# %% [markdown]
# ### [퀴즈5] 모듈 활용

# %% [markdown]
# Q.math 모듈의 pi를 출력하기 위한 수정 방법과 그 출력값을 올바르게 작성한 것을 고르세요.
# >from math import pi
# >
# >print(math.pi)
# 1. 수정 방법: print(math.pi)를 print(pi)로 수정 / 출력값: 2.718281828459045
# 2. 수정 방법: from math import pi를 import math로 수정 / 출력값: 3.141592653589793
# 3. 수정 방법: print(math.pi)를 print(math.e)로 수정 / 출력값: 3.141592653589793
#
# 정답 : 2

# %% [markdown]
# ### [실습4] import vs from-import

# %% [markdown]
# **어떻게 모듈을 불러오는게 좋을까요?**
#
# 모듈을 불러오는 방법에는 크게 2가지가 있습니다.
#
# - from a import b : a 모듈(혹은 패키지)에서 b 함수를 가져오겠다. b를 사용하기 위해선 b() 꼴 로 사용 가능
# - import a : a 모듈을 불러오겠다. a 모듈 안에있는 b 함수를 사용하기 위해선 a.b() 꼴로 사용해야함
#
# ---
# 앞에서 배웠던 두 모듈 - random과 math를 다르게 불러오는 방법을 배워봅시다.
#
# **이렇게 해봐요!**
# 1. from a import b를 이용해서 random의 randrange()를 불러와봅시다.
#
# 2. import a를 이용해서 math 모듈을 불러와봅시다.
#
# 3. 변수 var1에 random.randrange 함수를 이용해 1이상 10이하의 임의의 정수를 넣어봅시다.
#
# 4. 변수 var2에 math.log 함수를 이용해 log_{72}5184의 값을 넣어봅시다.
#
# 5. var1, var2를 출력하여 결과값을 확인해봅시다.
#
# **Tips**
# - random.randrange(x, y) 함수는 x부터 y-1까지의 숫자에서 임의의 숫자를 하나 반환합니다.

# %%
from random import randrange

import math

var1 = randrange(1, 11)

var2 = math.log(5184, 72)

print("var1:", var1)
print("var2:", var2)
# Out:
# var1: 10
# var2: 2.0

# %% [markdown]
# ### [실습5] 웹페이지 방문

# %% [markdown]
# **웹페이지가 어떻게 구성되어 있는지 확인해봅시다.**
#
# Python에서는 쉽게 웹페이지의 정보를 가져올 수 있는 urllib패키지를 제공합니다. 이 중에서 urllib.request.urlopen 함수는 해당 url의 html 파일을 가져옵니다.
#
# 위 함수를 이용해서 https://en.wikipedia.org/wiki/Lorem_ipsum 홈페이지의 정보를 가져와봅시다.
#
# **이렇게 해봐요!**
# 1. from-import를 이용해서 urllib패키지 안 request 모듈에서 urlopen 함수를 불러오는 코드를 작성해봅시다.
#
# 2. 다음 주소를 urlopen하고, read() 한 다음, 이를 utf-8으로 decode 한 결과를 변수 webpage에 넣어봅시다.
#
# >https://en.wikipedia.org/wiki/Lorem_ipsum
#
# 3. 변수 webpage를 출력해봅시다. 무엇이 나오나요?
#
#
# 이 문제는 제출 버튼이 없습니다. 실행 후 다음 문제로 넘어가주세요!

# %%
from urllib.request import urlopen

url = "https://en.wikipedia.org/wiki/Lorem_ipsum"

webpage = urlopen(url).read().decode('utf-8')

print(webpage)

# %% [markdown]
# ### [실습6] 로또 추첨기

# %% [markdown]
# **로또 1등 당첨 확률은 1/8,145,060! 과연 여러분은?**
#
# random 모듈에는 수를 임의로 추출할 수 있는 함수 randrange()가 존재합니다.
#
# - random.randrange(a, b) : a 이상 b 미만의 수를 임의로 뽑아서 반환해주는 함수
#
# ---
# 로또 게임은 1부터 45까지의 숫자 중 임의의 6개의 수를 맞추는 게임입니다. randrange()를 이용해서 여러분의 운을 시험해보세요!
#
# **이렇게 해봐요!**
# 1. random 모듈을 import해봅시다.
#
# 2. 빈 리스트를 담은 변수 lotto를 만들어봅시다.
#
# 3. lotto의 길이가 6이 될 때까지 다음 과정을 수행합니다.
#
# - 1부터 45까지의 수 중 하나를 임의로 뽑습니다.
# - 만약 뽑은 수가 리스트 lotto에 없으면 lotto에 추가하고, 있으면 수를 다시 뽑습니다.
# 4. lotto를 정렬해줍니다.
#
# 5. lotto를 출력하여 우리가 뽑은 로또번호를 확인해봅시다.

# %%
import random

lotto = []

while len(lotto) < 6:
    number = random.randrange(1, 46)
    if number not in lotto:
        lotto.append(number)

lotto.sort()

print(lotto)
# Out:
# [22, 25, 29, 30, 31, 44]

# %% [markdown]
# ### [요약] 모듈과 패키지

# %% [markdown]
# PPT

# %% [markdown]
# ### [미션] 계산기

# %% [markdown]
# **도전! 계산기의 달인**
#
# main.py에 cal.py를 불러들여 해당 파일의 함수들을 사용해보는 코드가 적혀있습니다.
#
# 이들이 동작되기 위해 cal.py를 구현해주세요!
#
# ---
# **미션! 해결해봅시다.**
#
# cal.py에 다음 함수(메서드)가 있는 모듈 cal를 만들어 주세요
#
# - plus(a, b) : a+b를 반환하는 함수
# - minus(a, b) : a-b를 반환하는 함수
# - times(a, b) : a*b를 반환하는 함수
# - divide(a, b) : a/b를 반환하는 함수
# - mod(a, b) : a%b를 반환하는 함수
#
# main.py에서 이 모듈을 불러와 실행해볼 수 있어요.

# %%
# main.py

import cal

a = 10
b = 5

_plus = cal.plus(a, b)
_minus = cal.minus(a, b)
_times = cal.times(a, b)
_divide = cal.divide(a, b)
_mod = cal.mod(a, b)

print(f"{a} + {b} = {_plus}")
print(f"{a} - {b} = {_minus}")
print(f"{a} * {b} = {_times}")
print(f"{a} / {b} = {_divide}")
print(f"{a} % {b} = {_mod}")

# %%
# cal.py

def plus(a, b):
    return a + b

def minus(a, b):
    return a - b

def times(a, b):
    return a * b

def divide(a, b):
    if b != 0:
        return a / b
    else:
        return "zzzz"

def mod(a, b):
    if b != 0:
        return a % b
    else:
        return "zzzz."

# %% [markdown]
# ### 3장을 닫으며

# %% [markdown]
# 3장을 완료하셨군요! 축하드립니다. 😉
# 이번 장의 내용을 통해 우리는 조금 더 큰 세계로 나아갈 수 있게 되었어요.
# 무슨 의미냐구요? 복습과 함께 이를 더 자세히 알아보아요!
#
# ---
# **1. 모듈**
#
# **Point I**
# 특정 목적을 가진 함수, 자료, 코드의 모임
#
# **Point II**
# 모듈 불러오기 - import 키워드를 이용해서 모듈을 사용
#
# >import random  #random 모듈을 불러온다
#
# **Point III**
# 모듈 사용하기 - .을 쓴 후에 모듈 속 함수/변수를 사용
#
# >import random
# >
# >print(random.randrange(0, 2)) #0 이상 2 미만 수 중 하나를 임의로 출력
#
# **Point IV**
# 모듈 만들기 - .py확장자의 파이썬 파일로 생성
#
# >     ## price.py
# americano = 4100
# cafe_latte = 4600
# ...
# >
# >     ## main.py
# import price
# print(price.americano) # 4100
#
# **Point V**
# 모듈 예시 I - math: 수학 연산을 도와주는 모듈
#
# >import math
# >
# >print(math.cos(0)) # cos(0)인 1.0을 출력
#
# **Point VI**
# 모듈 예시 II - random : 랜덤한 숫자를 선택하는 함수가 담긴 모듈
#
# >>import random
# >>
# >>print(random.randrange(1, 10))  # 1~9 중 하나를 랜덤으로 출력
#
# ---
# **2. 패키지**
# **Point I**
# 모듈을 폴더(디렉토리) 단위로 관리하는 것!
#
# **Point II**
# - import vs from-import
# import A : 불러올 장소(A)만을 명시한 것
#
# >import A
# A.func() # A 안의 함수 func를 사용하기 위해선 A.func() 꼴로 사용
#
# from A import func- 불러올 장소(A)와 불러올 변수/함수(func)을 명시한 것
#
# >from A import func
# func()  # A 안의 함수 func을 사용하기 위해선 func() 꼴로 사용
#
# **Point III**
# 모듈 vs 패키지
# - 모듈 : 변수와 함수, 코드를 모아둔 하나의 .py파일
# - 패키지 : 폴더(디렉토리)와 모듈로 구성되는 세트
#
# >     # [예시] 파이썬으로 게임 패키지를 만든다면?
# game/ #폴더
# &nbsp;&nbsp;&nbsp;&nbsp;    __init__.py
# &nbsp;&nbsp;&nbsp;&nbsp;    audio/
# &nbsp;&nbsp;&nbsp;&nbsp;    sprite/
# &nbsp;&nbsp;&nbsp;&nbsp;    script/
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;        __init__.py
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;        move.py #모듈
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;        attack.py
#  &nbsp;&nbsp;&nbsp;&nbsp;   ...
# ---
# 실제 파이썬을 사용할 때에는 여러 함수나 변수, 그리고 코드가 담긴 모듈과
# 이를 묶은 패키지를 통해 개발한다는 사실! 알고 계셨나요?
# 이러한 모듈 속 변수, 함수의 사용방법으로 데이터 분석과 웹 프로그래밍 등을 진행할 수 있어요!
#
# 다음 장은 아쉽게도 이번 강의의 마지막 장이에요 😢
# 성질과 할 수 일을 담은 새로운 형태인 객체에 대해서 배우고
# 이를 만들 수 있는 방법에 대해 다루어보고자 해요.
#
# 끝날 때까지는 끝난게 아니다
# 아직 끝이 아니에요! 포기하지 말고 달려봐요 💪
